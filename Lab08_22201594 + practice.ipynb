# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  if root == None:
    return None

  root.left, root.right  = root.right, root.left#, root.left
  convert_mirror(root.left)
  convert_mirror(root.right)
  return root

#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def find_smallest(root, level, level_min):
  if root is None:
    return None

  if level in level_min:
    if root.elem < level_min[level]:
      level_min[level] = root.elem
  else:
    level_min[level] = root.elem

  find_smallest(root.left,level+1,level_min)
  find_smallest(root.right,level+1,level_min)

def smallest_level(root):
  level_min = {}
  find_smallest(root,0,level_min)

  return level_min

#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 -5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# Task 3

# %%
def inorder_predecessor(root, x):

  def maximum(node):
    while node.right:
      node = node.right
    return node

  if x.left is not None:
    return maximum(x.left)
  else:
    return None

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 20: 14

# %% [markdown]
# Task 4

# %%
def LCA(root, x, y):

    if x.elem < root.elem and y.elem < root.elem:
        return LCA(root.left, x, y)


    elif x.elem > root.elem and y.elem > root.elem:
        return LCA(root.right, x, y)

    else:
        return root

# DRIVER CODE

root = BTNode(15)
n1 = BTNode(10)
n2 = BTNode(25)
n3 = BTNode(8)
n4 = BTNode(12)
n5 = BTNode(20)
n6 = BTNode(30)
n7 = BTNode(6)
n8 = BTNode(9)
n9 = BTNode(18)
n10 = BTNode(22)


root.left = n1
root.right = n2
n1.left = n3
n1.right = n4
n2.left = n5
n2.right = n6
n3.left = n7
n3.right = n8
n5.left = n9
n5.right = n10


lca_node = LCA(root, n7, n4)
print(f'LCA(6,12) = {lca_node.elem}')

lca_node = LCA(root, n5, n7)
print(f'LCA(20,6) = {lca_node.elem}')

lca_node = LCA(root, n9, n10)
print(f'LCA(18,22) = {lca_node.elem}')

lca_node = LCA(root, n5, n2)
print(f'LCA(20,25) = {lca_node.elem}')

lca_node = LCA(root, n1, n4)
print(f'LCA(10,12) = {lca_node.elem}')
# Out:
# LCA(6,12) = 10
# LCA(20,6) = 15
# LCA(18,22) = 20
# LCA(20,25) = 25
# LCA(10,12) = 10

# %% [markdown]
# BONUS TASK 1

# %%
def sum_tree(root):

    if root is None:
        return 0
    if root.left is None and root.right is None:
        return root.elem


    left_sum = sum_tree(root.left)
    right_sum = sum_tree(root.right)


    if root.left is None and root.right is not None:

        if root.right.elem == root.elem and right_sum == root.elem:
            return 2 * root.elem
        else:
            return -1
    elif root.right is None and root.left is not None:
        if root.left.elem == root.elem and left_sum == root.elem:
            return 2 * root.elem
        else:
            return -1
    else:

        if root.elem == left_sum + right_sum:
            return root.elem + left_sum + right_sum
        else:
            return -1

def is_sum_tree(root):
    if sum_tree(root) >= 0:
        return True
    else:
        return False


root = BTNode(26)
root.left = BTNode(10)
root.right = BTNode(3)
root.left.left = BTNode(4)
root.left.right = BTNode(6)
root.right.right = BTNode(3)

print("The given Binary Tree is a SumTree:", is_sum_tree(root))  # Expected Output: True
# Out:
# The given Binary Tree is a SumTree: True

# %% [markdown]
# Bonus Task 2

# %%
#WRITE THE FUNCTION BY YOURSELF
def find_level_diff(node, level = 0):
  if not node:
    return 0

  if level%2 == 1:
    return node.elem + find_level_diff(node.left, level+1) + find_level_diff(node.right, level+1)
  else:
      return -node.elem + find_level_diff(node.left, level+1) + find_level_diff(node.right, level+1)


root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8
difference = find_level_diff(root)
print("Difference between sums of odd and even level nodes:", difference)
# Out:
# Difference between sums of odd and even level nodes: 4

# %%
def inorder_predecessor(root, x):

    predecessor = None


    while root is not None:
        if x.elem <= root.elem:

            root = root.left
        else:

            predecessor = root
            root = root.right


    return predecessor

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14`
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 20: 14

# %%
def smallest_level(root):
  def find(root, level, level_min):
    if root is None:
      return None

    if level in level_min:
      if root.elem < level_min[level]:
        level_min[level] = root.elem
    else:
      level_min[level] = root.elem

    find(root.left,level+1,level_min)
    find(root.right,level+1,level_min)

  level_min = {}
  find(root,0,level_min)

  return level_min


#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 -5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# # **PRACTICE SHEET**

# %% [markdown]
# 1. Given two binary trees, find if both of them are identical or not.

# %%
def identical(r1,r2):

  if r1 is None and r2 is None:
    return "yes"

  if r1 is None or r2 is None or r1.elem != r2.elem:
    return "No"

  return identical(r1.left,r2.left) and identical(r1.right,r2.right)

root1 = BTNode(1)
n1 = BTNode(2)
n2 = BTNode(3)
root1.left = n1
root1.right =n2

root2 = BTNode(1)
m1 = BTNode(2)
m2 = BTNode(3)
root2.left = m1
root2.right = m2

root3 = BTNode(1)
m_1 = BTNode(2)
m_2 = BTNode(3)
root3.left = m_2
root3.right = m_1

#Driver code
print(identical(root1,root2))
print(identical(root1,root3))
# Out:
# yes
# No

# %% [markdown]
# # **convert a binary tree into its mirror**

# %%
def convert_mirror(root):

  if root is None:
    return None
  root.left,root.right = root.right, root.left

  convert_mirror(root.left)
  convert_mirror(root.right)

  return root

root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# traversing techniques

# %%
def inorder(root):
  if root is None:
    return None
  inorder(root.left)
  print(root.elem,end=",")
  inorder(root.right)

def preorder(root):
  if root is None:
    return None
  print(root.elem,end=",")
  preorder(root.left)
  preorder(root.right)

def postorder(root):
  if root is None:
    return None
  postorder(root.left)
  postorder(root.right)
  print(root.elem,end=",")

root = BTNode(70)
n1 = BTNode(50)
n2 = BTNode(90)
n3 = BTNode(40)
n4 = BTNode(60)
n5 = BTNode(80)
n6 = BTNode(95)
n7 = BTNode(20)
n8 = BTNode(75)
n9 = BTNode(85)
n10 = BTNode(99)

root.left = n1
root.right = n2
n1.left = n3
n1.right = n4
n3.left = n7
n2.left = n5
n2.right = n6
n5.left = n8
n5.right = n9
n6.right = n10
print("inorder:")
inorder(root)
print("preorder:")
preorder(root)
print("postorder:")
postorder(root)
# Out:
# inorder:
# 20,40,50,60,70,75,80,85,90,95,99,preorder:
# 70,50,40,20,60,90,80,75,85,95,99,postorder:
# 20,40,60,50,75,85,80,99,95,90,70,

# %% [markdown]
# Given a binary tree, find if it is height balanced or not. A tree is height balanced if the
# difference between heights of left and right subtrees is not more than one for all nodes of
# the tree.

# %%
def get_height(root):
  if root is None:
    return 0

  left_height = get_height(root.left)
  right_height = get_height(root.right)

  if left_height > right_height:
    return left_height+1
  else:
    return right_height +1

def is_balanced(root):
  if root is None:
    return 0

  left_height = get_height(root.left)
  right_height = get_height(root.right)

  if (left_height - right_height) > 1 or (right_height - left_height > 1):
    return False
  return True


root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)
root.left = n1
root.right = n2
n1.left = n3
n1.right = n4
print('height',get_height(root))
print(is_balanced(root))

root2 = BTNode(1)
n1 = BTNode(2)
n2 = BTNode(3)
root2.left = n1
n1.right = n2

print(is_balanced(root2))
# Out:
# height 3
# True
# False

# %% [markdown]
# 4. Given a binary tree, check whether all of its nodes have the value equal to the sum of
# their child nodes.

# %%
def sum_checker(root):
  if root is None:
        return True


  if root.left is None and root.right is None:
      return True

  if root.left is None:
    left_sum = 0
  else:
    left_sum = root.left.elem

  if root.right is None:
    right_sum = 0
  else:
    right_sum = root.right.elem

  if root.elem != left_sum + right_sum:
    return False

  return sum_checker(root.left) and sum_checker(root.right)
# Test case for a single node tree
root = BTNode(10)
n1 = BTNode(10)
root.left = n1
print(sum_checker(root))  # Should return True

# Test case for a tree with children
root1 = BTNode(1)
root1.left = BTNode(4)
root1.right = BTNode(3)
root1.left.left = BTNode(5)
root1.left.right = BTNode(0)
print(sum_checker(root1))  #Should return False
# Out:
# True
# False

# %% [markdown]
# 5. Given a binary tree, find the largest value in each level.

# %%
def findlargest(root, dict ={}, level = 0):
  if root is None:
    return
  if level not in dict or root.elem > dict[level]:
    dict[level] = root.elem

  find_largest(root.left,dict,level+1)
  find_largest(root.right,dict,level+1)

  return dict

root = BTNode(4)
n1 = BTNode (9)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(5)
n5 = BTNode(7)

root.left = n1
root.right = n2
n1.left = n3
n1.right = n4
n2.right = n5
print(findlargest(root))
# Out:
# {0: 4, 1: 9, 2: 7}

# %% [markdown]
# Given a binary tree, check if it has duplicate values.

# %%
class BTNode:
    def __init__(self, value):
        self.elem = value
        self.left = None
        self.right = None

def duplicate_checker(root, l1=None):
    if l1 is None:
        l1 = []

    if root is None:
        return "duplicate not found"

    if root.elem in l1:
        return "duplicate found"
    else:
        l1 += [root.elem]

    left_check = duplicate_checker(root.left, l1)
    if left_check == "duplicate found":
        return left_check

    right_check = duplicate_checker(root.right, l1)
    if right_check == "duplicate found":
        return right_check

    return "duplicate not found"

# Test case
root = BTNode(1)
n1 = BTNode(2)
n2 = BTNode(3)
n3 = BTNode(2)
root.left = n1
root.right = n2
n2.right = n3
print(duplicate_checker(root))  # Expected to return "duplicate found"

root = BTNode(1)
n1 = BTNode(20)
n2 = BTNode(3)
n3 = BTNode(4)

root.left = n1
root.right = n2
n2.right = n3
print(duplicate_checker(root))
# Out:
# duplicate found
# duplicate not found

# %%
def duplicate_checker(root):
  if root is None:
    return "Duplicate - No"
  nodes = inorder(root)
  emp =[]

  for i in nodes:
        if i in emp:
            return 'Duplicate - Yes'
        emp += [i]
  return "Duplicate - No"

def inorder(root, l1=None):
    if l1 is None:
        l1 = []
    if root is None:
        return l1
    inorder(root.left, l1)
    l1 += [root.elem]
    inorder(root.right, l1)
    return l1

# Test case
root = BTNode(1)
n1 = BTNode(2)
n2 = BTNode(3)
n3 = BTNode(2)
root.left = n1
root.right = n2
n2.right = n3
print(duplicate_checker(root))  # Expected to return "duplicate found"

root = BTNode(1)
n1 = BTNode(20)
n2 = BTNode(3)
n3 = BTNode(4)

root.left = n1
root.right = n2
n2.right = n3
print(duplicate_checker(root))
# Out:
# Duplicate - Yes
# Duplicate - No

# %% [markdown]
# BST CODE

# %%
class Node:
  def __init__(self,elem):
    self.elem = elem
    self.left = self.right = None

def addNode(root,i):
  if i<root.elem and root.left == None:
    n = Node(i)
    root.left = n

  elif i>root.elem and root.right == None:
    n = Node(i)
    root.right = n

  if i<root.elem and root.left!= None:
    addNode(root.left, i)
  elif i>root.elem and root.right != None:
    addNode(root.right, i)

def deleteNode(root,key):
  if root is None:
    return root

# %%
def subtract_summation(root):
  if root is None:
    return 0
  left_sum = summation(root.left)
  right_sum =summation(root.right)

  return (left_sum-right_sum)

def summation(root):
  if root is None:
    return 0

  return root.elem + summation(root.left) + summation(root.right)

root = BTNode(71)
n1 = BTNode(27)
n2 = BTNode(62)
n3 = BTNode(80)
n4 = BTNode(75)
n5 = BTNode(41)
n6 = BTNode(3)
n7 = BTNode(87)
n8 = BTNode(56)
n9 = BTNode(19)
n10 = BTNode(89)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n3.left = n7
n3.right = n8

n2.left = n5
n2.right = n6

n6.left= n9
n6.right = n10

print(subtract_summation(root))
# Out:
# 111

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root = tree_construction([None, 15, 18, 6, 28, 16, None, 23, None, -1, None, 3, None, None, -2, -6])
postorder(root)
print()
inorder(root)
print()
preorder(root)
# Out:
# -1,28,3,16,18,-2,-6,23,6,15,
# 28,-1,18,16,3,15,6,-2,23,-6,
# 15,18,28,-1,16,3,6,23,-2,-6,

# %%
def recFunc(x):
  if x<=2:
    return 0
  return x+recFunc(x//2)
print(recFunc(16))
# Out:
# 28

# %%
def isPrime(x):
  if x< 2:
    return False
  return isDivisible(x, x-1)
def isDivisible(n, divisor):
  if divisor == 1:
    return True
  if n % divisor == 0:
    return False
  return isDivisible(n,divisor - 1)

print(isPrime(43))
print(isPrime(22))
# Out:
# True
# False

# %% [markdown]
# \
